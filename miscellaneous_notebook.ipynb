# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
bom_movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross.value_counts()
# Out:
# title                           studio   domestic_gross  foreign_gross  year
# xXx: The Return of Xander Cage  Par.     44900000.0      301200000      2017    1
# I Am Number Four                BV       55100000.0      94800000       2011    1
# How to Be Single                WB (NL)  46800000.0      65500000       2016    1
# How to Train Your Dragon        P/DW     217600000.0     277300000      2010    1
# How to Train Your Dragon 2      Fox      177000000.0     444500000      2014    1
#                                                                                ..
# Source Code                     Sum.     54700000.0      92600000       2011    1
# South of the Border             CLS      199000.0        70800          2010    1
# Southpaw                        Wein.    52400000.0      39500000       2015    1
# Southside with You              RAtt.    6300000.0       208000         2016    1
# ...

# %%
movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep = '\t')
movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
movie_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budgets['id'].value_counts()
# Out:
# 4      58
# 53     58
# 61     58
# 65     58
# 69     58
#        ..
# 85     57
# 100    57
# 96     57
# 92     57
# 97     57
# Name: id, Length: 100, dtype: int64

# %%
budgets['production_budget'].value_counts()
# Out:
# $20,000,000     231
# $10,000,000     212
# $30,000,000     177
# $15,000,000     173
# $25,000,000     171
#                ...
# $86,000,000       1
# $658,000          1
# $136,200,000      1
# $3,716,946        1
# $56,200,000       1
# Name: production_budget, Length: 509, dtype: int64

# %%
budgets[budgets['production_budget'] < '$10,000'].sort_values(by = ['production_budget'], ascending = False)
# Out:
#       id  release_date                  movie production_budget  \
# 5001   2  Sep 24, 2010                 Buried        $1,987,650
# 5002   3  Apr 21, 2015           The Marine 4        $1,950,000
# 5008   9   Jun 3, 2011              Submarine        $1,900,000
# 5013  14  Dec 31, 2015                  Vaalu        $1,900,000
# 5011  12  Jun 29, 2007         Chacun sa nuit        $1,900,000
# ...   ..           ...                    ...               ...
# 5245  46  Apr 24, 1998    Two Girls and a Guy        $1,000,000
# 5244  45  Nov 21, 2001  Sidewalks of New York        $1,000,000
# 5243  44   Aug 1, 2008           Frozen River        $1,000,000
# 5242  43   Aug 3, 2005                Junebug        $1,000,000
# 5251  52   Dec 7, 2001          No Man's Land        $1,000,000
#
#      domestic_gross worldwide_gross
# 5001     $1,044,143     $21,270,290
# 5002             $0              $0
# 5008       $467,602      $4,581,937
# 5013             $0         $12,444
# ...

# %%
budgets[budgets['id'] == 4].head(15)
# Out:
#       id  release_date                                movie production_budget  \
# 3      4   May 1, 2015              Avengers: Age of Ultron      $330,600,000
# 103    4  Mar 27, 2009                  Monsters vs. Aliens      $175,000,000
# 203    4  Jul 15, 2016                         Ghostbusters      $144,000,000
# 303    4  May 19, 1999  Star Wars Ep. I: The Phantom Menace      $115,000,000
# 403    4  Dec 14, 2018                       Mortal Engines      $100,000,000
# 503    4  Sep 29, 2006                          Open Season       $85,000,000
# 603    4  Dec 25, 1997                          The Postman       $80,000,000
# 703    4   Aug 8, 2003                             S.W.A.T.       $70,000,000
# 803    4  Sep 14, 2012           Resident Evil: Retribution       $65,000,000
# 903    4  Jan 11, 2013                       Gangster Squad       $60,000,000
# 1003   4  Apr 10, 1998                       City of Angels       $55,000,000
# ...

# %%
#setting up connection to database

conn = sqlite3.connect('im.db')
cur = conn.cursor()

# %%
db_tables = pd.read_sql("""

SELECT name
FROM sqlite_master
WHERE type = 'table';

""", conn)

db_tables
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
movie_basics = pd.read_sql("""

SELECT * 
FROM movie_basics

""", conn)

movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
movie_basics['genres'].str.split(',').explode().value_counts()
# Out:
# Documentary    51640
# Drama          49883
# Comedy         25312
# Thriller       11883
# Horror         10805
# Action         10335
# Romance         9372
# Biography       8722
# Crime           6753
# Adventure       6465
# Family          6227
# History         6225
# Mystery         4659
# Music           4314
# Fantasy         3516
# Sci-Fi          3365
# Animation       2799
# Sport           2234
# News            1551
# Musical         1430
# War             1405
# Western          467
# Reality-TV        98
# Talk-Show         50
# Adult             25
# Short             11
# Game-Show          4
# Name: genres, dtype: int64

# %%
movie_basics["genres"] = movie_basics["genres"].str.split(",")
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# shows all rows where runtime_minutes are null
null_rows = movie_basics.loc[movie_basics['runtime_minutes'].isnull()]
null_rows
# Out:
#          movie_id                                      primary_title  \
# 3       tt0069204                                    Sabse Bada Sukh
# 6       tt0112502                                            Bigfoot
# 8       tt0139613                                         O Silêncio
# 16      tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 21      tt0250404                                          Godfather
# ...           ...                                                ...
# 146131  tt9915790                                    Bobbyr Bondhura
# 146138  tt9916428                                The Secret of China
# 146140  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                                    Dankyavar Danka
# 146143  tt9916754                     Chico Albuquerque - Revelações
#
#                                            original_title  start_year  \
# ...

# %%
movie_basics.loc[movie_basics['genres'].isnull() & movie_basics['runtime_minutes'].isnull()]
# Out:
#           movie_id                                      primary_title  \
# 16       tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 44       tt0330811                                Regret Not Speaking
# 619     tt10011238                                     Happy Birthday
# 632     tt10011402                            Martha: A Picture Story
# 728     tt10025972                                         Maza Algar
# ...            ...                                                ...
# 145984   tt9893012                                      Black Minutes
# 146036   tt9900680                              Youtuber Horror Movie
# 146048   tt9902734     Josh Groban Bridges from Madison Square Garden
# 146107   tt9910922       Doctor Who Augmented Reality: Times Magazine
# 146129   tt9914942                         La vida sense la Sara Amat
#
#                                            original_title  start_year  \
# ...

# %%
# removing rows from movie_basics with null genre and runtime
new_df = movie_basics.drop(movie_basics.loc[movie_basics['genres'].isnull() & movie_basics['runtime_minutes'].isnull()].index)
len(movie_basics) - len(new_df)
# Out:
# 3236

# %%
movie_basics.runtime_minutes.value_counts().sort_values(ascending = True)
# Out:
# 540.0        1
# 363.0        1
# 263.0        1
# 1184.0       1
# 406.0        1
#           ...
# 95.0      2549
# 100.0     2662
# 85.0      2915
# 80.0      3526
# 90.0      7131
# Name: runtime_minutes, Length: 367, dtype: int64

# %%
multiple_values = movie_basics.primary_title.value_counts()
movie_basics[movie_basics.primary_title.isin(multiple_values.index[multiple_values.gt(20)])]
# Out:
#          movie_id primary_title original_title  start_year  runtime_minutes  \
# 27295   tt2075392          Home           Yurt        2011             76.0
# 27922   tt2089701          Home           Home        2011              7.0
# 28069   tt2093100          Home            Dom        2011            127.0
# 32554   tt2224026          Home           Home        2015             94.0
# 38079   tt2372760          Home          Hemma        2013             90.0
# 38947   tt2393825          Home           Home        2013            112.0
# 42535   tt2545384          Home           Home        2016             87.0
# 44656   tt2650038          Home           Home        2012              3.0
# 47561   tt2821866          Home           Home        2013             92.0
# 56247   tt3289416          Home       Dom tsah        2012             26.0
# 60589   tt3506448          Home         A Casa        2012             70.0
# ...

# %%
#movie_basics.drop('start_year', axis=1, inplace=True)

# %%
directors = pd.read_sql("""

SELECT *
FROM directors

""", conn)

directors.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291174 entries, 0 to 291173
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   291174 non-null  object
#  1   person_id  291174 non-null  object
# dtypes: object(2)
# memory usage: 4.4+ MB

# %%
directors.value_counts()
# Out:
# movie_id   person_id
# tt2249786  nm4630460    52
#            nm1667641    52
#            nm3952326    52
#            nm3911770    52
#            nm3863962    52
#                         ..
# tt3835080  nm0957772     1
# tt3835110  nm7064225     1
# tt7083156  nm1962933     1
# tt3835134  nm7775933     1
# tt4105968  nm1297226     1
# Length: 163535, dtype: int64

# %%
# removes duplicate rows that share the same movie_id and person_id
director_duplicates = directors.duplicated(keep = False)
directors[director_duplicates]
# Out:
#          movie_id   person_id
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 8       tt0996958   nm2286991
# 9       tt0996958   nm2286991
# 10      tt0999913   nm0527109
# ...           ...         ...
# 291160  tt8992390   nm0504267
# 291161  tt8992390   nm0504267
# 291162  tt8992390   nm0504267
# 291167  tt8999892  nm10122247
# 291168  tt8999892  nm10122247
#
# [182316 rows x 2 columns]

# %%
directors_no_dups = directors.drop_duplicates()
directors_no_dups.value_counts()
# Out:
# movie_id   person_id
# tt9916754  nm9272490    1
# tt2861666  nm0813949    1
# tt2862288  nm5196865    1
# tt2862220  nm5642484    1
# tt2862198  nm5140747    1
#                        ..
# tt5607934  nm5481490    1
# tt5607916  nm8047651    1
#            nm4194194    1
# tt5607810  nm4160810    1
# tt0063540  nm0712540    1
# Length: 163535, dtype: int64

# %%
directors_no_dups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163535 entries, 0 to 291173
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   163535 non-null  object
#  1   person_id  163535 non-null  object
# dtypes: object(2)
# memory usage: 3.7+ MB

# %%
directors_no_dups[directors_no_dups.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [movie_id, person_id]
# Index: []

# %%
known_for = pd.read_sql("""

SELECT *
FROM known_for
""", conn)

known_for.head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
known_for.value_counts()
# Out:
# person_id  movie_id
# nm9993680  tt8295580    1
# nm2101079  tt7547864    1
# nm2101095  tt0490172    1
#            tt5356300    1
# nm2101106  tt0411272    1
#                        ..
# nm4852350  tt3605780    1
#            tt5562254    1
# nm4852353  tt2182099    1
#            tt2203308    1
# nm0000002  tt0037382    1
# Length: 1638260, dtype: int64

# %%
movie_akas = pd.read_sql("""

SELECT *
FROM movie_akas
""", conn)

movie_akas.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
movie_ratings = pd.read_sql("""

SELECT *
FROM movie_ratings
""", conn)

movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
persons = pd.read_sql("""

SELECT *
FROM persons
""", conn)

persons.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
persons.drop(['birth_year', 'death_year', 'primary_profession'], axis=1, inplace=True)
persons.head()
# Out:
#    person_id       primary_name
# 0  nm0061671  Mary Ellen Bauder
# 1  nm0061865       Joseph Bauer
# 2  nm0062070         Bruce Baum
# 3  nm0062195       Axel Baumann
# 4  nm0062798        Pete Baxter

# %%
persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   person_id     606648 non-null  object
#  1   primary_name  606648 non-null  object
# dtypes: object(2)
# memory usage: 9.3+ MB

# %%
persons.value_counts()
# Out:
# person_id  primary_name
# nm9993680  Christopher-Lawson Palmer    1
# nm2829362  Heather Howe                 1
# nm2829342  António Morais               1
# nm2829328  Xi He                        1
# nm2829296  Jose Montesinos              1
#                                        ..
# nm5914861  Kate Madison                 1
# nm5914859  Monica Cioffi                1
# nm5914858  Alex Zalban                  1
# nm5914773  Pedro Luis Nadal García      1
# nm0000002  Lauren Bacall                1
# Length: 606648, dtype: int64

# %%
principals = pd.read_sql("""

SELECT *
FROM principals
""", conn)

principals.head()
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
principals.job.isna().sum()
# Out:
# 850502

# %%
principals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   movie_id    1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   person_id   1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
principals.drop(['job', 'characters'], axis=1, inplace=True)
principals.head()
# Out:
#     movie_id  ordering  person_id  category
# 0  tt0111414         1  nm0246005     actor
# 1  tt0111414         2  nm0398271  director
# 2  tt0111414         3  nm3739909  producer
# 3  tt0323808        10  nm0059247    editor
# 4  tt0323808         1  nm3579312   actress

# %%
writers = pd.read_sql("""

SELECT *
FROM writers
""", conn)

writers.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
writers.value_counts()
# Out:
# movie_id   person_id
# tt4050462  nm3601272    83
#            nm5134804    83
#            nm0340236    83
#            nm0250080    83
#            nm8337609    83
#                         ..
# tt5048688  nm6999080     1
# tt5048612  nm7603072     1
#            nm7603070     1
#            nm7603067     1
# tt0063540  nm0023551     1
# Length: 178352, dtype: int64

# %%
writers.person_id.value_counts()
# Out:
# nm6935209    543
# nm1546474    257
# nm0000636    180
# nm2780568    173
# nm4664031    158
#             ...
# nm7772599      1
# nm5190153      1
# nm0500535      1
# nm0876011      1
# nm4557566      1
# Name: person_id, Length: 122576, dtype: int64

# %%
v = writers.person_id.value_counts()
writers[writers.person_id.isin(v.index[v.gt(10)])]
# Out:
#          movie_id  person_id
# 69      tt1138442  nm0150916
# 76      tt1323592  nm2598931
# 77      tt1323592  nm2598931
# 91      tt1336608  nm1615610
# 93      tt1340107  nm0421314
# ...           ...        ...
# 255800  tt8833552  nm0952982
# 255801  tt8833552  nm0952982
# 255802  tt8833552  nm0952982
# 255803  tt8833552  nm0952982
# 255804  tt8833552  nm0952982
#
# [51345 rows x 2 columns]

# %%
writer_duplicates = writers.duplicated(keep = False)
writers[writer_duplicates]
# Out:
#           movie_id   person_id
# 6        tt0878654   nm0284943
# 7        tt0878654   nm0284943
# 8        tt0878654   nm0284943
# 46      tt10140002   nm0104200
# 47      tt10140002   nm0104200
# ...            ...         ...
# 255822   tt8865986   nm6676529
# 255823   tt8865986  nm10058226
# 255824   tt8865986  nm10058226
# 255846   tt8948466  nm10098149
# 255847   tt8948466  nm10098149
#
# [104011 rows x 2 columns]

# %%
writers_no_dups = writers.drop_duplicates()
writers_no_dups.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 255868    False
# 255869    False
# 255870    False
# 255871    False
# 255872    False
# Length: 178352, dtype: bool

# %%
writers_no_dups.value_counts()
# Out:
# movie_id   person_id
# tt9916754  nm9272490    1
# tt2672334  nm0314399    1
# tt2672660  nm1803417    1
# tt2672548  nm2897690    1
#            nm1802378    1
#                        ..
# tt5248546  nm2973161    1
# tt5248342  nm1847630    1
# tt5248210  nm0139158    1
# tt5248042  nm7769690    1
# tt0063540  nm0023551    1
# Length: 178352, dtype: int64

# %%
writers.value_counts()
# Out:
# movie_id   person_id
# tt4050462  nm3601272    83
#            nm5134804    83
#            nm0340236    83
#            nm0250080    83
#            nm8337609    83
#                         ..
# tt5048688  nm6999080     1
# tt5048612  nm7603072     1
#            nm7603070     1
#            nm7603067     1
# tt0063540  nm0023551     1
# Length: 178352, dtype: int64

# %%
dis_person_id = pd.read_sql("""

SELECT DISTINCT person_id, p.movie_id, category, per.primary_name, per.primary_profession
FROM principals AS p
JOIN directors AS d
    USING(person_id)
JOIN writers AS w
    USING(person_id)
JOIN persons AS per 
   USING(person_id);


""", conn)

dis_person_id.head()
# Out:
#    person_id   movie_id  category       primary_name        primary_profession
# 0  nm0398271  tt0111414  director       Frank Howson     actor,writer,producer
# 1  nm0362736  tt0323808  director        Robin Hardy     actor,writer,director
# 2  nm0330974  tt0417610   actress       Esther Goris   actress,writer,director
# 3  nm1145057  tt0417610  director  Alejandro Chomski  director,writer,producer
# 4  nm3745712  tt0469152    editor      Chris Modoono    writer,director,editor

# %%
dis_person_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155531 entries, 0 to 155530
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   person_id           155531 non-null  object
#  1   movie_id            155531 non-null  object
#  2   category            155531 non-null  object
#  3   primary_name        155531 non-null  object
#  4   primary_profession  155300 non-null  object
# dtypes: object(5)
# memory usage: 5.9+ MB

# %%
dis_person_id.person_id.value_counts()
# Out:
# nm0695177    80
# nm2794335    72
# nm0290556    69
# nm0189883    66
# nm3132095    64
#              ..
# nm3721156     1
# nm2838316     1
# nm3106778     1
# nm0480039     1
# nm2058359     1
# Name: person_id, Length: 67501, dtype: int64

# %%
dis_person_id[dis_person_id['person_id'] == 'nm0695177']
# Out:
#         person_id    movie_id category primary_name       primary_profession
# 544     nm0695177   tt1948150    actor  Prakash Raj  actor,producer,director
# 763     nm0695177  tt10300630    actor  Prakash Raj  actor,producer,director
# 1116    nm0695177   tt1814797    actor  Prakash Raj  actor,producer,director
# 2119    nm0695177   tt2186943    actor  Prakash Raj  actor,producer,director
# 3736    nm0695177   tt1625856    actor  Prakash Raj  actor,producer,director
# ...           ...         ...      ...          ...                      ...
# 147380  nm0695177   tt8066574    actor  Prakash Raj  actor,producer,director
# 148186  nm0695177   tt7019820    actor  Prakash Raj  actor,producer,director
# 151303  nm0695177   tt7380372    actor  Prakash Raj  actor,producer,director
# 151481  nm0695177   tt8108220    actor  Prakash Raj  actor,producer,director
# 153407  nm0695177   tt8188610    actor  Prakash Raj  actor,producer,director
#
# [80 rows x 5 columns]

# %%
# creating multi-index to group all movies a person has worked in
mult_index_persons = dis_person_id.set_index(['person_id', 'movie_id']).sort_index()

# %%
mult_index_persons.category.value_counts()
# Out:
# director               99015
# actor                  20253
# writer                 10274
# producer                8696
# cinematographer         4754
# self                    3927
# editor                  3798
# actress                 3742
# composer                 752
# production_designer      199
# archive_footage          120
# archive_sound              1
# Name: category, dtype: int64

# %%
mult_index_persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 155531 entries, ('nm0000080', 'tt0069049') to ('nm9993573', 'tt10299418')
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   category            155531 non-null  object
#  1   primary_name        155531 non-null  object
#  2   primary_profession  155300 non-null  object
# dtypes: object(3)
# memory usage: 13.6+ MB

# %%
film_people = pd.read_sql("""

SELECT DISTINCT p.movie_id, person_id, category, per.primary_name, per.primary_profession
FROM principals AS p
JOIN directors AS d
    USING(person_id)
JOIN writers AS w
    USING(person_id)
JOIN persons AS per 
   USING(person_id);

""", conn)

film_people.head()
# Out:
#     movie_id  person_id  category       primary_name        primary_profession
# 0  tt0111414  nm0398271  director       Frank Howson     actor,writer,producer
# 1  tt0323808  nm0362736  director        Robin Hardy     actor,writer,director
# 2  tt0417610  nm0330974   actress       Esther Goris   actress,writer,director
# 3  tt0417610  nm1145057  director  Alejandro Chomski  director,writer,producer
# 4  tt0469152  nm3745712    editor      Chris Modoono    writer,director,editor

# %%
film_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155531 entries, 0 to 155530
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            155531 non-null  object
#  1   person_id           155531 non-null  object
#  2   category            155531 non-null  object
#  3   primary_name        155531 non-null  object
#  4   primary_profession  155300 non-null  object
# dtypes: object(5)
# memory usage: 5.9+ MB

# %%
film_people.person_id.value_counts()
# Out:
# nm0695177    80
# nm2794335    72
# nm0290556    69
# nm0189883    66
# nm3132095    64
#              ..
# nm3721156     1
# nm2838316     1
# nm3106778     1
# nm0480039     1
# nm2058359     1
# Name: person_id, Length: 67501, dtype: int64

# %%
film_people[film_people['person_id'] == 'nm0695177']
# Out:
#           movie_id  person_id category primary_name       primary_profession
# 544      tt1948150  nm0695177    actor  Prakash Raj  actor,producer,director
# 763     tt10300630  nm0695177    actor  Prakash Raj  actor,producer,director
# 1116     tt1814797  nm0695177    actor  Prakash Raj  actor,producer,director
# 2119     tt2186943  nm0695177    actor  Prakash Raj  actor,producer,director
# 3736     tt1625856  nm0695177    actor  Prakash Raj  actor,producer,director
# ...            ...        ...      ...          ...                      ...
# 147380   tt8066574  nm0695177    actor  Prakash Raj  actor,producer,director
# 148186   tt7019820  nm0695177    actor  Prakash Raj  actor,producer,director
# 151303   tt7380372  nm0695177    actor  Prakash Raj  actor,producer,director
# 151481   tt8108220  nm0695177    actor  Prakash Raj  actor,producer,director
# 153407   tt8188610  nm0695177    actor  Prakash Raj  actor,producer,director
#
# [80 rows x 5 columns]

# %%
principals.head()
# Out:
#     movie_id  ordering  person_id  category
# 0  tt0111414         1  nm0246005     actor
# 1  tt0111414         2  nm0398271  director
# 2  tt0111414         3  nm3739909  producer
# 3  tt0323808        10  nm0059247    editor
# 4  tt0323808         1  nm3579312   actress

# %%
principals.value_counts()
# Out:
# movie_id   ordering  person_id  category
# tt9916754  10        nm9275317  cinematographer    1
# tt2705972  1         nm5517988  actress            1
# tt2706008  4         nm1644795  composer           1
#            3         nm1531645  producer           1
#            2         nm4858177  writer             1
#                                                   ..
# tt5452310  2         nm0468723  actress            1
#            1         nm7913890  actress            1
# tt5452252  10        nm0880000  cinematographer    1
#            9         nm8356883  composer           1
# tt0063540  1         nm0474801  actor              1
# Length: 1028186, dtype: int64

# %%
writers_no_dups.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
writers_no_dups.rename(columns={'person_id': 'writer_id'}, inplace=True)
# Out:
# /Users/chriskucewicz/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
directors_no_dups.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 4  tt0878654  nm0089502
# 5  tt0878654  nm2291498

# %%
directors_no_dups.rename(columns={'person_id': 'director_id'}, inplace=True)
# Out:
# /Users/chriskucewicz/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
persons.head()
# Out:
#    person_id       primary_name
# 0  nm0061671  Mary Ellen Bauder
# 1  nm0061865       Joseph Bauer
# 2  nm0062070         Bruce Baum
# 3  nm0062195       Axel Baumann
# 4  nm0062798        Pete Baxter

# %%
persons.value_counts()
# Out:
# person_id  primary_name
# nm9993680  Christopher-Lawson Palmer    1
# nm2829362  Heather Howe                 1
# nm2829342  António Morais               1
# nm2829328  Xi He                        1
# nm2829296  Jose Montesinos              1
#                                        ..
# nm5914861  Kate Madison                 1
# nm5914859  Monica Cioffi                1
# nm5914858  Alex Zalban                  1
# nm5914773  Pedro Luis Nadal García      1
# nm0000002  Lauren Bacall                1
# Length: 606648, dtype: int64

# %%
film_people = pd.read_sql("""

SELECT  DISTINCT movie_id, primary_title, original_title, start_year, runtime_minutes, averagerating, numvotes, primary_name, primary_profession, genres
FROM movie_basics
JOIN movie_ratings
    USING(movie_id)
JOIN directors_no_dups
    USING(movie_id)
JOIN writers_no_dups
    USING(movie_id)

""", conn)

movie_db_info.info()

# %%
#film_people = pd.concat([principals, directors_no_dups, writers_no_dups, persons])
#film_people.head()

# %%
#movie_people = principals.merge(persons, on='person_id', how='left')
#movie_people.head()

# %%
#movie_people = movie_people.merge(directors_no_dups, on = 'person_id', how = 'left')
#movie_people

# %%
#movie_people.merge(directors_no_dups, on = 'person_id', how = 'inner')

# %%
movie_people = principals.merge(persons, on = 'person_id', how = 'left')
movie_people

# %%
movie_people = movie_people.merge(directors_no_dups, left_on = ['person_id', 'movie_id'], right_on = ['director_id', 'movie_id'], how = 'left')

# %%
movie_people = movie_people.merge(writers_no_dups, left_on = ['person_id', 'movie_id'], right_on = ['writer_id', 'movie_id'], how = 'left')

# %%
movie_people

# %%
movie_people.to_csv('movie_people.csv', index=False)

# %%
movies = movie_basics.merge(movie_people, on = 'movie_id', how = 'inner')

# %%
movies.to_csv('movies.csv', index=False)

# %%
movie_db_info = pd.read_sql("""

SELECT  DISTINCT movie_id, primary_title, original_title, start_year, runtime_minutes, averagerating, numvotes, primary_name, primary_profession, genres
FROM movie_basics
JOIN movie_ratings
    USING(movie_id)
JOIN directors_no_dups
    USING(movie_id)
JOIN writers_no_dups
    USING(movie_id)

""", conn)

movie_db_info.info()

# %%
movie_db_info.isna().sum()

# %%
movie_db_info.dropna(subset=['runtime_minutes', 'primary_profession', 'genres'], inplace=True)

# %%
movie_db_info.info()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(movie_db_info['runtime_minutes']);

# %%
movie_db_info['runtime_minutes'].hist();
